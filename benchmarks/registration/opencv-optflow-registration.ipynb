# %% [markdown]
# # OpenCV Optical Flow & Folding Correction
#
# Uses OpenCV dense optical flow methods to compute displacement fields
# between image pairs, then corrects folding with DVFopt.
#
# Optical flow is not designed for medical image registration, but it
# produces dense displacement fields that frequently contain folding
# (negative Jacobian determinants) â€” making it a good stress test.
#
# Methods tested:
#
# 1. **Farneback** â€” polynomial expansion, fast, often folds
# 2. **TV-L1** â€” total variation L1, better edge-preserving
# 3. **DIS (Dense Inverse Search)** â€” real-time optical flow
#
# **Requirements:**
# ```
# pip install opencv-python-headless
# ```

# %%
import os, sys
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))

import time
import importlib

import numpy as np
import matplotlib.pyplot as plt

from dvfopt import jacobian_det2D, iterative_serial
from dvfopt.viz import (
    plot_grid_before_after,
    plot_checkerboard_before_after,
    plot_neg_jdet_neighborhoods,
)

HAS_CV2 = importlib.util.find_spec("cv2") is not None
print(f"OpenCV: {'available' if HAS_CV2 else 'MISSING â€” pip install opencv-python-headless'}")
from benchmark_utils import (
    get_output_dir, save_figure, save_results_csv, save_summary_json, log_run_header, log_run_footer, results_to_rows, show_and_save, reset_figure_counter,
)
# Out:
# OpenCV: available

# %%
METHOD = "slsqp"
NOTEBOOK_NAME = "opencv-optflow"
OUTPUT_DIR = get_output_dir(METHOD, NOTEBOOK_NAME, base="../output")
reset_figure_counter()
summary = log_run_header(METHOD, NOTEBOOK_NAME, OUTPUT_DIR)
# Out:
# ========================================================================
#   Benchmark  : opencv-optflow
#   Method     : slsqp
#   Timestamp  : 2026-04-17T12:56:43
#   Output dir : ..\output\slsqp\opencv-optflow
# ========================================================================

# %% [markdown]
# ## Configuration

# %%
IMAGE_SIZE = 64
JDET_THRESHOLD = 0.01

# Real image paths (set both to use real data instead of synthetic)
FIXED_IMAGE_PATH = None
MOVING_IMAGE_PATH = None

# %% [markdown]
# ## Generate (or load) test images
#
# We use images with enough structural difference to produce large,
# fold-inducing displacements.

# %%
def make_test_image(size, shapes):
    img = np.zeros((size, size), dtype=np.float32)
    yy, xx = np.mgrid[0:size, 0:size].astype(np.float32)
    for cy, cx, ry, rx, intensity in shapes:
        mask = ((yy - cy) / ry) ** 2 + ((xx - cx) / rx) ** 2 <= 1.0
        img[mask] = intensity
    return img


if FIXED_IMAGE_PATH is not None and MOVING_IMAGE_PATH is not None:
    import cv2
    fixed_np = cv2.imread(FIXED_IMAGE_PATH, cv2.IMREAD_GRAYSCALE).astype(np.float32) / 255.0
    moving_np = cv2.imread(MOVING_IMAGE_PATH, cv2.IMREAD_GRAYSCALE).astype(np.float32) / 255.0
    IMAGE_SIZE = fixed_np.shape[0]
    print(f"Loaded real images: {fixed_np.shape}")
else:
    S = IMAGE_SIZE
    fixed_np = make_test_image(S, [
        (S*0.35, S*0.35, S*0.15, S*0.12, 0.9),
        (S*0.60, S*0.55, S*0.18, S*0.14, 0.7),
        (S*0.30, S*0.65, S*0.10, S*0.10, 0.5),
        (S*0.70, S*0.30, S*0.12, S*0.08, 0.6),
    ])
    moving_np = make_test_image(S, [
        (S*0.30, S*0.40, S*0.18, S*0.10, 0.9),
        (S*0.65, S*0.50, S*0.15, S*0.17, 0.7),
        (S*0.25, S*0.60, S*0.12, S*0.08, 0.5),
        (S*0.72, S*0.25, S*0.10, S*0.12, 0.6),
    ])
    print(f"Generated synthetic {S}x{S} test images")

fig, axes = plt.subplots(1, 2, figsize=(8, 3.5))
axes[0].imshow(fixed_np, cmap="gray"); axes[0].set_title("Fixed")
axes[1].imshow(moving_np, cmap="gray"); axes[1].set_title("Moving")
for ax in axes: ax.axis("off")
plt.tight_layout()
show_and_save(OUTPUT_DIR)
# Out:
# Generated synthetic 64x64 test images
#   [saved] ..\output\slsqp\opencv-optflow\figure_01.png

# %% [markdown]
# ## Helpers

# %%
def to_dvfopt(dy, dx):
    H, W = dy.shape
    deformation = np.zeros((3, 1, H, W), dtype=np.float64)
    deformation[1, 0] = dy
    deformation[2, 0] = dx
    return deformation


def show_jdet_map(jac, title, ax):
    jac2d = np.squeeze(jac)
    vmax = max(abs(jac2d.min()), abs(jac2d.max()), 1.0)
    im = ax.imshow(jac2d, cmap="RdBu", vmin=-vmax, vmax=vmax)
    n_neg = int((jac2d <= 0).sum())
    ax.set_title(f"{title}\nneg={n_neg}  min={jac2d.min():+.3f}  max={jac2d.max():+.3f}", fontsize=9)
    ax.axis("off")
    return im


def summarize_and_correct(deformation, label, reg_time):
    phi_init = np.stack([deformation[1, 0], deformation[2, 0]])
    jac_init = jacobian_det2D(phi_init)
    n_neg = int((jac_init <= 0).sum())
    H, W = deformation.shape[-2:]

    print(f"\n{'='*70}")
    print(f"  {label}  |  {H}x{W}  |  neg Jdet: {n_neg}  |  flow time: {reg_time:.4f}s")
    print(f"  Before: min Jdet={jac_init.min():+.6f}  max Jdet={jac_init.max():+.6f}")
    print(f"{'='*70}")

    if n_neg == 0:
        print("  No folding detected — skipping correction.")
        fig, ax = plt.subplots(1, 1, figsize=(4.5, 4), constrained_layout=True)
        im = show_jdet_map(jac_init, f"{label} — Jdet (no folding)", ax)
        fig.colorbar(im, ax=ax, shrink=0.85, label="Jacobian det")
        show_and_save(OUTPUT_DIR)
        return {"n_neg_init": 0, "n_neg_final": 0, "time": 0.0, "l2": 0.0,
                "min_jdet": float(jac_init.min()), "reg_time": reg_time}

    t0 = time.perf_counter()
    phi = iterative_serial(deformation.copy(), verbose=1, threshold=JDET_THRESHOLD)
    corr_time = time.perf_counter() - t0

    jac_final = jacobian_det2D(phi)
    n_neg_final = int((jac_final <= 0).sum())
    l2 = float(np.sqrt(np.sum((phi - phi_init) ** 2)))

    print(f"  Correction: {corr_time:.2f}s  |  neg: {n_neg} -> {n_neg_final}  "
          f"|  min Jdet: {jac_init.min():+.4f} -> {jac_final.min():+.4f}  |  L2: {l2:.4f}")

    # Show Jdet BEFORE and AFTER side-by-side with a shared colorbar
    fig, axes = plt.subplots(1, 2, figsize=(8, 4), constrained_layout=True)
    im = show_jdet_map(jac_init, f"{label} - Before correction", axes[0])
    show_jdet_map(jac_final, f"{label} - After correction", axes[1])
    fig.colorbar(im, ax=axes, location="right", shrink=0.85, label="Jacobian det")
    fig.suptitle(f"{label} - Jacobian Determinant Before vs After", fontsize=11)
    show_and_save(OUTPUT_DIR)

    #plot_grid_before_after(deformation, phi, title=label)
    #plot_checkerboard_before_after(deformation, phi, title=label)
    #plot_neg_jdet_neighborhoods(deformation, phi, title=label)

    return {"n_neg_init": n_neg, "n_neg_final": n_neg_final,
            "time": corr_time, "l2": l2, "min_jdet": float(jac_final.min()),
            "reg_time": reg_time}

# %% [markdown]
# ---
# ## Method 1: Farneback Optical Flow
#
# Dense polynomial-expansion optical flow.  Fast but noisy â€” frequently
# produces folding even on smooth image pairs.

# %%
results = {}

if HAS_CV2:
    import cv2

    # Convert to uint8 for OpenCV
    fixed_u8 = (fixed_np * 255).astype(np.uint8)
    moving_u8 = (moving_np * 255).astype(np.uint8)

    t0 = time.perf_counter()
    flow = cv2.calcOpticalFlowFarneback(
        fixed_u8, moving_u8,
        flow=None,
        pyr_scale=0.5,
        levels=5,
        winsize=15,
        iterations=10,
        poly_n=7,
        poly_sigma=1.5,
        flags=0,
    )
    reg_time = time.perf_counter() - t0

    # OpenCV flow: (H, W, 2) with [..., 0]=dx, [..., 1]=dy
    dx = flow[..., 0].astype(np.float64)
    dy = flow[..., 1].astype(np.float64)
    results["Farneback"] = summarize_and_correct(to_dvfopt(dy, dx), "Farneback", reg_time)
else:
    print("OpenCV not available - skipping")
# Out:
# ======================================================================
#   Farneback  |  64x64  |  neg Jdet: 179  |  flow time: 0.0039s
#   Before: min Jdet=-8.265801  max Jdet=+9.228404
# ======================================================================
# [init] Grid 64x64  |  threshold=0.01  |  method=SLSQP
# [init] Neg-Jdet pixels: 179  |  min Jdet: -8.265801
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 27
#      23
#      24     # OpenCV flow: (H, W, 2) with [..., 0]=dx, [..., 1]=dy
#      25     dx = flow[..., 0].astype(np.float64)
#      26     dy = flow[..., 1].astype(np.float64)
# ---> 27     results["Farneback"] = summarize_and_correct(to_dvfopt(dy, dx), "Farneback", reg_time)
#      28 else:
#      29     print("OpenCV not available - skipping")
#
# Cell In[7], line 40, in summarize_and_correct(deformation, label, reg_time)
#      36         return {"n_neg_init": 0, "n_neg_final": 0, "time": 0.0, "l2": 0.0,
#      37                 "min_jdet": float(jac_init.min()), "reg_time": reg_time}
#      38
#      39     t0 = time.perf_counter()
# ---> 40     phi = iterative_serial(deformation.copy(), verbose=1, threshold=JDET_THRESHOLD)
#      41     corr_time = time.perf_counter() - t0
#      42
#      43     jac_final = jacobian_det2D(phi)
#
# File ~\Documents\GitHub\UCI-iGravi\deformation-field-processing\dvfopt\core\slsqp\iterative.py:205, in iterative_serial(deformation_i, method_name, verbose, save_path, plot_every, plot_callback, threshold, err_tol, max_iterations, max_per_index_iter, max_minimize_iter, enforce_shoelace, enforce_injectivity, injectivity_threshold, max_doublings, debug)
#     202     debug._on_iter_start(iteration, neg_index_tuple, jacobian_matrix, phi)
#     203 _cb = debug.plot_callback if debug is not None else plot_callback
#     204 jacobian_matrix, quality_matrix, submatrix_size, per_index_iter, (cy, cx) = \
# --> 205     _serial_fix_pixel(
#     206         neg_index_tuple, phi, phi_init, jacobian_matrix,
#     207         slice_shape, near_cent_dict, window_counts,
#     208         max_per_index_iter, max_minimize_iter,
#     209         max_window, threshold, err_tol, method_name, verbose,
#     210         error_list, num_neg_jac, min_jdet_list, iter_times,
#     211         enforce_shoelace=enforce_shoelace,
#     212         enforce_injectivity=enforce_injectivity,
#     213         injectivity_threshold=injectivity_threshold,
#     214         plot_callback=_cb,
#     215         deformation_i=deformation_i,
#     216         min_window=global_min_window,
#     217         labeled=_labeled_neg,
#     218     )
#     219 if debug is not None:
#     220     debug._on_iter_end(iteration, neg_index_tuple, (cy, cx),
#     221                        jacobian_matrix, phi, submatrix_size, per_index_iter)
#
# File ~\Documents\GitHub\UCI-iGravi\deformation-field-processing\dvfopt\core\solver.py:465, in _serial_fix_pixel(neg_index_tuple, phi, phi_init, jacobian_matrix, slice_shape, near_cent_dict, window_counts, max_per_index_iter, max_minimize_iter, max_window, threshold, err_tol, method_name, verbose, error_list, num_neg_jac, min_jdet_list, iter_times, enforce_shoelace, enforce_injectivity, injectivity_threshold, plot_callback, deformation_i, min_window, labeled)
#     462 _eff_max_iter = _adaptive_maxiter(2 * _opt_sy * _opt_sx, max_minimize_iter)
#     464 # Run optimisation directly — no process pool
# --> 465 result_x, elapsed, opt_success = _optimize_single_window(
#     466     phi_sub_flat, phi_init_sub_flat, opt_size,
#     467     opt_is_at_edge, opt_window_reached_max,
#     468     threshold, _eff_max_iter, method_name,
#     469     enforce_shoelace=enforce_shoelace,
#     470     enforce_injectivity=enforce_injectivity,
#     471     injectivity_threshold=injectivity_threshold,
#     472 )
#     473 iter_times.append(elapsed)
#     474 if not opt_success:
#
# File ~\Documents\GitHub\UCI-iGravi\deformation-field-processing\dvfopt\core\solver.py:296, in _optimize_single_window(phi_sub_flat, phi_init_sub_flat, submatrix_size, is_at_edge, window_reached_max, threshold, max_minimize_iter, method_name, enforce_shoelace, enforce_injectivity, injectivity_threshold)
#     288 constraints = _build_constraints(
#     289     phi_sub_flat, submatrix_size, is_at_edge, window_reached_max, threshold,
#     290     enforce_shoelace=enforce_shoelace,
#     291     enforce_injectivity=enforce_injectivity,
#     292     injectivity_threshold=injectivity_threshold,
#     293 )
#     295 t0 = time.time()
# --> 296 result = minimize(
#     297     lambda phi1: objective_euc(phi1, phi_init_sub_flat),
#     298     phi_sub_flat,
#     299     jac=True,
#     300     constraints=constraints,
#     301     options={"maxiter": max_minimize_iter, "disp": False},
#     302     method=method_name,
#     303 )
#     304 elapsed = time.time() - t0
#     305 if not np.all(np.isfinite(result.x)):
#
# File c:\Users\Andy\Documents\GitHub\UCI-iGravi\deformation-field-processing\.venv\Lib\site-packages\scipy\optimize\_minimize.py:750, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     747     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     748                            **options)
#     749 elif meth == 'slsqp':
# --> 750     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     751                           constraints, callback=callback, **options)
#     752 elif meth == 'trust-constr':
#     753     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     754                                        bounds, constraints,
#     755                                        callback=callback, **options)
#
# File c:\Users\Andy\Documents\GitHub\UCI-iGravi\deformation-field-processing\.venv\Lib\site-packages\scipy\optimize\_slsqp_py.py:435, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     429 slsqp(m, meq, x, xl, xu, fx, c, g, a, acc, majiter, mode, w, jw,
#     430       alpha, f0, gs, h1, h2, h3, h4, t, t0, tol,
#     431       iexact, incons, ireset, itermx, line,
#     432       n1, n2, n3)
#     434 if mode == 1:  # objective and constraint evaluation required
# --> 435     fx = wrapped_fun(x)
#     436     c = _eval_constraint(x, cons)
#     438 if mode == -1:  # gradient evaluation required
#
# File c:\Users\Andy\Documents\GitHub\UCI-iGravi\deformation-field-processing\.venv\Lib\site-packages\scipy\optimize\_optimize.py:304, in _clip_x_for_func.<locals>.eval(x)
#     303 def eval(x):
# --> 304     x = _check_clip_x(x, bounds)
#     305     return func(x)
#
# File c:\Users\Andy\Documents\GitHub\UCI-iGravi\deformation-field-processing\.venv\Lib\site-packages\scipy\optimize\_optimize.py:311, in _check_clip_x(x, bounds)
#     310 def _check_clip_x(x, bounds):
# --> 311     if (x < bounds[0]).any() or (x > bounds[1]).any():
#     312         warnings.warn("Values in x were outside bounds during a "
#     313                       "minimize step, clipping to bounds",
#     314                       RuntimeWarning, stacklevel=3)
#     315         x = np.clip(x, bounds[0], bounds[1])
#
# File c:\Users\Andy\Documents\GitHub\UCI-iGravi\deformation-field-processing\.venv\Lib\site-packages\numpy\_core\_methods.py:57, in _any(a, axis, dtype, out, keepdims, where)
#      53 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      54           initial=_NoValue, where=True):
#      55     return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# ---> 57 def _any(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      58     # By default, return a boolean for any and all
#      59     if dtype is None:
#      60         dtype = bool_dt
#
# KeyboardInterrupt:

# %% [markdown]
# ## Method 2: TV-L1 Optical Flow
#
# Total-variation L1 dual formulation.  Better edge preservation but
# can still produce folding at discontinuities.

# %%
import cv2
HAS_OPTFLOW = HAS_CV2 and hasattr(cv2, "optflow")

if HAS_OPTFLOW:
    tvl1 = cv2.optflow.DualTVL1OpticalFlow_create()
    tvl1.setTau(0.25)
    tvl1.setLambda(0.15)
    tvl1.setTheta(0.3)
    tvl1.setScalesNumber(5)
    tvl1.setWarpingsNumber(5)

    t0 = time.perf_counter()
    flow = tvl1.calc(fixed_u8, moving_u8, None)
    reg_time = time.perf_counter() - t0

    dx = flow[..., 0].astype(np.float64)
    dy = flow[..., 1].astype(np.float64)
    results["TV-L1"] = summarize_and_correct(to_dvfopt(dy, dx), "TV-L1", reg_time)
else:
    print("TV-L1 skipped — requires opencv-contrib-python (pip install opencv-contrib-python-headless)")
# Out:
# ======================================================================
#   TV-L1  |  64x64  |  neg Jdet: 38  |  flow time: 0.7137s
#   Before: min Jdet=-5.560686  max Jdet=+5.643958
# ======================================================================
# [init] Grid 64x64  |  threshold=0.01  |  method=SLSQP
# [init] Neg-Jdet pixels: 38  |  min Jdet: -5.560686
# [iter    1]  fix ( 17, 34)  win 26x12  neg_jdet    15  min_jdet -1.626743  L2 4.2230  sub-iters 3
# [iter    2]  fix ( 28, 35)  win 11x11  neg_jdet     7  min_jdet -0.437132  L2 4.4159  sub-iters 1
# [iter    3]  fix ( 38, 22)  win 7x7  neg_jdet     4  min_jdet +0.000997  L2 4.4306  sub-iters 1
# [iter    4]  fix ( 44, 12)  win 7x6  neg_jdet     0  min_jdet +0.010000  L2 4.4306  sub-iters 1
# [done] All Jdet > threshold after iter 4
#
# ============================================================
#   SUMMARY  (SLSQP)
# ------------------------------------------------------------
#   Grid size        : 64 x 64
#   Iterations       : 4
#   Neg-Jdet     38 ->     0
#   Min Jdet  -5.560686 -> +0.010000
#   L2 error         : 4.430645
#   Time             : 0.74s
# ============================================================
#   Correction: 0.74s  |  neg: 38 -> 0  |  min Jdet: -5.5607 -> +0.0100  |  L2: 4.4306
#   [saved] ..\output\slsqp\opencv-optflow\figure_02.png

# %% [markdown]
# ## Method 3: DIS (Dense Inverse Search)
#
# Real-time dense optical flow.  Very fast, but the speed/quality
# trade-off means more folding.

# %%
if HAS_CV2:
    dis = cv2.DISOpticalFlow_create(cv2.DISOPTICAL_FLOW_PRESET_MEDIUM)

    t0 = time.perf_counter()
    flow = dis.calc(fixed_u8, moving_u8, None)
    reg_time = time.perf_counter() - t0

    dx = flow[..., 0].astype(np.float64)
    dy = flow[..., 1].astype(np.float64)
    results["DIS"] = summarize_and_correct(to_dvfopt(dy, dx), "DIS", reg_time)
else:
    print("OpenCV not available â€” skipping")
# Out:
# ======================================================================
#   DIS  |  64x64  |  neg Jdet: 0  |  flow time: 0.0130s
#   Before: min Jdet=+0.116711  max Jdet=+2.904001
# ======================================================================
#   No folding detected — skipping correction.
#   [saved] ..\output\slsqp\opencv-optflow\figure_03.png

# %% [markdown]
# ---
# ## Summary

# %%
if results:
    print(f"{'Method':<12s}  {'Flow (s)':>10s}  {'Neg init':>10s}  {'Neg final':>10s}  "
          f"{'Corr (s)':>10s}  {'L2 Error':>10s}  {'Min Jdet':>10s}")
    print("-" * 80)
    for name, r in results.items():
        print(f"{name:<12s}  {r['reg_time']:>10.4f}  {r['n_neg_init']:>10d}  "
              f"{r['n_neg_final']:>10d}  {r['time']:>10.2f}  "
              f"{r['l2']:>10.4f}  {r['min_jdet']:>+10.6f}")

    # Bar chart
    methods = list(results.keys())
    x = np.arange(len(methods))

    fig, axes = plt.subplots(1, 3, figsize=(14, 4))

    ax = axes[0]
    ax.bar(x - 0.15, [results[m]["n_neg_init"] for m in methods], 0.3,
           label="Before", color="tab:red", alpha=0.7)
    ax.bar(x + 0.15, [results[m]["n_neg_final"] for m in methods], 0.3,
           label="After", color="tab:green", alpha=0.7)
    ax.set_xticks(x); ax.set_xticklabels(methods)
    ax.set_ylabel("Neg Jdet pixels")
    ax.set_title("Folding: Before vs After")
    ax.legend()

    ax = axes[1]
    ax.bar(x - 0.15, [results[m]["reg_time"] for m in methods], 0.3,
           label="Optical flow", color="tab:blue", alpha=0.7)
    ax.bar(x + 0.15, [results[m]["time"] for m in methods], 0.3,
           label="Correction", color="tab:orange", alpha=0.7)
    ax.set_xticks(x); ax.set_xticklabels(methods)
    ax.set_ylabel("Time (s)")
    ax.set_title("Flow vs Correction Time")
    ax.legend()

    ax = axes[2]
    ax.bar(methods, [results[m]["l2"] for m in methods], color="tab:purple", alpha=0.7)
    ax.set_ylabel("L2 Error")
    ax.set_title("Correction L2 Deviation")

    plt.suptitle("OpenCV Optical Flow â€” DVFopt Correction", fontsize=13)
    plt.tight_layout()
    show_and_save(OUTPUT_DIR)
# Out:
# Method          Flow (s)    Neg init   Neg final    Corr (s)    L2 Error    Min Jdet
# --------------------------------------------------------------------------------
# Farneback         0.0016         179           0       31.37     19.1584   +0.010000
# TV-L1             0.6624          38           0        0.98      4.4305   +0.010000
# DIS               0.0124           0           0        0.00      0.0000   +0.116711

# %%
# --- Save results ---
if 'results' in dir() and isinstance(results, dict) and results:
    rows, cols = results_to_rows(results)
    save_results_csv(rows, cols, OUTPUT_DIR)
    summary = log_run_footer(summary, results)
    save_summary_json(summary, OUTPUT_DIR)
elif 'mag_results' in dir():
    rows, cols = results_to_rows(mag_results)
    save_results_csv(rows, cols, OUTPUT_DIR, name='results_magnitude')
    if 'density_results' in dir():
        rows2, cols2 = results_to_rows(density_results)
        save_results_csv(rows2, cols2, OUTPUT_DIR, name='results_density')
    combined = {**mag_results, **density_results} if 'density_results' in dir() else mag_results
    summary = log_run_footer(summary, combined)
    save_summary_json(summary, OUTPUT_DIR)
else:
    save_summary_json(summary, OUTPUT_DIR)
    print('No results dict found; saved summary only.')
