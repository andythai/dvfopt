# %% [markdown]
# # VoxelMorph Registration & Folding Correction
#
# End-to-end example: train a small [VoxelMorph](https://github.com/voxelmorph/voxelmorph)
# registration network on synthetic 2D images, extract the predicted displacement
# field, and correct any folding (negative Jacobian determinants) with the iterative
# SLSQP method.
#
# **Pipeline:**
# 1. Generate a synthetic dataset of 2D images (random circles/ellipses)
# 2. Build and train a `VxmPairwise` model (unsupervised, MSE + smoothness loss)
# 3. Register a held-out test pair and extract the displacement field
# 4. Convert to project convention `(3, 1, H, W)` with `[dz=0, dy, dx]`
# 5. Check for negative Jacobian determinants
# 6. Correct folding with `iterative_parallel`
# 7. Visualise before/after grids

# %% [markdown]
# ## Install VoxelMorph
#
# Run `setup-venv.bat` from the project root to create a `.venv` with all
# dependencies (including GPU-accelerated PyTorch and VoxelMorph).  Then
# select the `.venv` kernel in VS Code before running the notebook.
#
# If you've already set up the venv, skip straight to the imports cell.

# %%
# Verify the environment — run this cell to check everything is importable.
import importlib, sys
print(f'Python: {sys.executable}')
for pkg in ['numpy', 'scipy', 'matplotlib', 'SimpleITK', 'nibabel', 'pandas',
            'torch', 'voxelmorph', 'neurite']:
    try:
        m = importlib.import_module(pkg)
        v = getattr(m, '__version__', '?')
        print(f'  {pkg:15s} {v}')
    except ImportError:
        print(f'  {pkg:15s} *** MISSING — run setup-venv.bat ***')
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu128
# Requirement already satisfied: torch in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (2.10.0)
# Requirement already satisfied: torchvision in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (0.25.0)
# Requirement already satisfied: filelock in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: setuptools in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (from torch) (82.0.1)
# Requirement already satisfied: numpy in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (from torchvision) (2.4.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (from torchvision) (12.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages)
# Collecting git+https://github.com/adalca/neurite.git
#   Cloning https://github.com/adalca/neurite.git to C:\Users\Andy\AppData\Local\Temp\pip-req-build-ii1ej_02
#   Resolved https://github.com/adalca/neurite.git to commit 4cac56f09ada217c64ec102fccafac3b1fbb60a2
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: neurite
#   Building wheel for neurite (pyproject.toml): started
#   Building wheel for neurite (pyproject.toml): finished with status 'done'
#   Created wheel for neurite: filename=neurite-0.2-py3-none-any.whl size=72214 sha256=efe6c99573cdcb881d2661597a88b19df2cde01822ef1c114613800457b0ec4a
#   Stored in directory: C:\Users\Andy\AppData\Local\Temp\pip-ephem-wheel-cache-czfnplm1\wheels\94\bc\e4\40c87a648e4c638347dad7ff7f82ad3b3c6e095aa354e00ab8
# Successfully built neurite
# Installing collected packages: neurite
#   Attempting uninstall: neurite
#     Found existing installation: neurite 0.2
#     Uninstalling neurite-0.2:
#       Successfully uninstalled neurite-0.2
# Successfully installed neurite-0.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages)
#   Running command git clone --filter=blob:none --quiet https://github.com/adalca/neurite.git 'C:\Users\Andy\AppData\Local\Temp\pip-req-build-ii1ej_02'
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages)
# Collecting git+https://github.com/voxelmorph/voxelmorph.git
#   Cloning https://github.com/voxelmorph/voxelmorph.git to C:\Users\Andy\AppData\Local\Temp\pip-req-build-_s9xjg4q
#   Resolved https://github.com/voxelmorph/voxelmorph.git to commit 6fea3e8722c3db7edeffc663700acb0d5bcbb3c3
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: voxelmorph
#   Building wheel for voxelmorph (pyproject.toml): started
#   Building wheel for voxelmorph (pyproject.toml): finished with status 'done'
#   Created wheel for voxelmorph: filename=voxelmorph-0.2-py3-none-any.whl size=45886 sha256=bf7addc5c27b07e829f888d3fb7cfd188eb37bb7bca0cd587e15662e80a218c6
#   Stored in directory: C:\Users\Andy\AppData\Local\Temp\pip-ephem-wheel-cache-mr1hsiic\wheels\13\24\06\5321a36f84920f689ded35a08331e4be4d0ef619cd611dac16
# Successfully built voxelmorph
# Installing collected packages: voxelmorph
#   Attempting uninstall: voxelmorph
#     Found existing installation: voxelmorph 0.2
#     Uninstalling voxelmorph-0.2:
#       Successfully uninstalled voxelmorph-0.2
# Successfully installed voxelmorph-0.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages)
#   Running command git clone --filter=blob:none --quiet https://github.com/voxelmorph/voxelmorph.git 'C:\Users\Andy\AppData\Local\Temp\pip-req-build-_s9xjg4q'
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages)
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Collecting numpy
#   Using cached numpy-2.4.3-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting scipy
#   Using cached scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting kiwisolver
#   Using cached kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Collecting pillow
#   Using cached pillow-12.1.1-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.62.1-cp313-cp313-win_amd64.whl.metadata (119 kB)
# Collecting packaging>=20.0 (from matplotlib)
#   Using cached packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl (8.1 MB)
# Using cached numpy-2.4.3-cp313-cp313-win_amd64.whl (12.3 MB)
# Using cached scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
# Using cached kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Using cached pillow-12.1.1-cp313-cp313-win_amd64.whl (7.0 MB)
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.62.1-cp313-cp313-win_amd64.whl (2.3 MB)
# Using cached packaging-26.0-py3-none-any.whl (74 kB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, pyparsing, pillow, packaging, numpy, kiwisolver, fonttools, cycler, scipy, python-dateutil, contourpy, matplotlib
#
#   Attempting uninstall: six
#
#     Found existing installation: six 1.17.0
#
#     Uninstalling six-1.17.0:
#
#    ----------------------------------------  0/12 [six]
#    ----------------------------------------  0/12 [six]
#    ----------------------------------------  0/12 [six]
#    ----------------------------------------  0/12 [six]
#    ----------------------------------------  0/12 [six]
#    ----------------------------------------  0/12 [six]
#    ----------------------------------------  0/12 [six]
#       Successfully uninstalled six-1.17.0
#    ----------------------------------------  0/12 [six]
#   Attempting uninstall: pyparsing
#    ----------------------------------------  0/12 [six]
#     Found existing installation: pyparsing 3.3.2
#    ----------------------------------------  0/12 [six]
#     Uninstalling pyparsing-3.3.2:
#    ----------------------------------------  0/12 [six]
#       Successfully uninstalled pyparsing-3.3.2
#    ----------------------------------------  0/12 [six]
#    --- ------------------------------------  1/12 [pyparsing]
#    --- ------------------------------------  1/12 [pyparsing]
#    --- ------------------------------------  1/12 [pyparsing]
#   Attempting uninstall: pillow
#    --- ------------------------------------  1/12 [pyparsing]
#     Found existing installation: pillow 12.1.1
#    --- ------------------------------------  1/12 [pyparsing]
#    ------ ---------------------------------  2/12 [pillow]
#     Uninstalling pillow-12.1.1:
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#       Successfully uninstalled pillow-12.1.1
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#    ------ ---------------------------------  2/12 [pillow]
#   Attempting uninstall: packaging
#    ------ ---------------------------------  2/12 [pillow]
#     Found existing installation: packaging 26.0
#    ------ ---------------------------------  2/12 [pillow]
#     Uninstalling packaging-26.0:
#    ------ ---------------------------------  2/12 [pillow]
#       Successfully uninstalled packaging-26.0
#    ------ ---------------------------------  2/12 [pillow]
#    ---------- -----------------------------  3/12 [packaging]
#    ---------- -----------------------------  3/12 [packaging]
#   Attempting uninstall: numpy
#    ---------- -----------------------------  3/12 [packaging]
#     Found existing installation: numpy 2.4.3
#    ---------- -----------------------------  3/12 [packaging]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#     Uninstalling numpy-2.4.3:
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#       Successfully uninstalled numpy-2.4.3
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#   Attempting uninstall: kiwisolver
#    ------------- --------------------------  4/12 [numpy]
#     Found existing installation: kiwisolver 1.5.0
#    ------------- --------------------------  4/12 [numpy]
#     Uninstalling kiwisolver-1.5.0:
#    ------------- --------------------------  4/12 [numpy]
#       Successfully uninstalled kiwisolver-1.5.0
#    ------------- --------------------------  4/12 [numpy]
#    ---------------- -----------------------  5/12 [kiwisolver]
#   Attempting uninstall: fonttools
#    ---------------- -----------------------  5/12 [kiwisolver]
#     Found existing installation: fonttools 4.62.1
#    ---------------- -----------------------  5/12 [kiwisolver]
#    -------------------- -------------------  6/12 [fonttools]
#     Uninstalling fonttools-4.62.1:
#    -------------------- -------------------  6/12 [fonttools]
#       Successfully uninstalled fonttools-4.62.1
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#   Attempting uninstall: cycler
#    -------------------- -------------------  6/12 [fonttools]
#     Found existing installation: cycler 0.12.1
#    -------------------- -------------------  6/12 [fonttools]
#     Uninstalling cycler-0.12.1:
#    -------------------- -------------------  6/12 [fonttools]
#       Successfully uninstalled cycler-0.12.1
#    -------------------- -------------------  6/12 [fonttools]
#   Attempting uninstall: scipy
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------------- -------------  8/12 [scipy]
#     Found existing installation: scipy 1.17.1
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#     Uninstalling scipy-1.17.1:
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#       Successfully uninstalled scipy-1.17.1
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#    -------------------------- -------------  8/12 [scipy]
#   Attempting uninstall: python-dateutil
#    -------------------------- -------------  8/12 [scipy]
#     Found existing installation: python-dateutil 2.9.0.post0
#    -------------------------- -------------  8/12 [scipy]
#     Uninstalling python-dateutil-2.9.0.post0:
#    -------------------------- -------------  8/12 [scipy]
#       Successfully uninstalled python-dateutil-2.9.0.post0
#    -------------------------- -------------  8/12 [scipy]
#    ------------------------------ ---------  9/12 [python-dateutil]
#    ------------------------------ ---------  9/12 [python-dateutil]
#    ------------------------------ ---------  9/12 [python-dateutil]
#   Attempting uninstall: contourpy
#    ------------------------------ ---------  9/12 [python-dateutil]
#     Found existing installation: contourpy 1.3.3
#    ------------------------------ ---------  9/12 [python-dateutil]
#     Uninstalling contourpy-1.3.3:
#    ------------------------------ ---------  9/12 [python-dateutil]
#       Successfully uninstalled contourpy-1.3.3
#    ------------------------------ ---------  9/12 [python-dateutil]
#    --------------------------------- ------ 10/12 [contourpy]
#    --------------------------------- ------ 10/12 [contourpy]
#    --------------------------------- ------ 10/12 [contourpy]
#    ------------------------------------ --- 11/12 [matplotlib]
#
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages\~-mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages\~-mpy'.
#   You can safely remove it manually.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\Andy\\Documents\\GitHub\\degu-registration\\.venv\\Lib\\site-packages\\matplotlib\\backends\\_backend_agg.cp313-win_amd64.pyd'
# Check the permissions.

# %% [markdown]
# ## Imports

# %%
import os
import time

import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

os.environ['NEURITE_BACKEND'] = 'pytorch'
os.environ['VXM_BACKEND'] = 'pytorch'

import neurite as ne
import voxelmorph as vxm

from modules.dvfopt import jacobian_det2D, iterative_parallel
from modules.dvfviz import (
    plot_grid_before_after,
    plot_checkerboard_before_after,
    plot_neg_jdet_neighborhoods,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 import time
#       4 import numpy as np
# ----> 5 import matplotlib.pyplot as plt
#       6 import torch
#       7 import torch.nn as nn
#
# File c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages\matplotlib\__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages\matplotlib\rcsetup.py:26
#      23 import numpy as np
#      25 from matplotlib import _api, cbook
# ---> 26 from matplotlib.backends import BackendFilter, backend_registry
#      27 from matplotlib.cbook import ls_mapper
#      28 from matplotlib.colors import Colormap, is_color_like
#
# File c:\Users\Andy\Documents\GitHub\degu-registration\.venv\Lib\site-packages\matplotlib\backends\__init__.py:1
# ----> 1 from .registry import BackendFilter, backend_registry  # noqa: F401
#       3 # NOTE: plt.switch_backend() (called at import time) will add a "backend"
#       4 # attribute here for backcompat.
#       5 _QT_FORCE_QT5_BINDING = False
#
# ModuleNotFoundError: No module named 'matplotlib.backends.registry'

# %% [markdown]
# ## Configuration

# %%
# --- Image / dataset ---
IMAGE_SIZE = 64          # H = W for the synthetic images
NUM_TRAIN_IMAGES = 200   # number of synthetic images for training
NUM_TEST_PAIRS = 4       # held-out pairs to register after training

# --- Model ---
NB_FEATURES = [16, 32, 32, 32, 16]   # UNet encoder/decoder feature counts
INTEGRATION_STEPS = 7                 # 0 = direct regression, >0 = diffeomorphic

# --- Training ---
EPOCHS = 200
STEPS_PER_EPOCH = 50
LR = 1e-3
LAMBDA_SMOOTH = 0.05     # weight for the spatial-gradient (smoothness) loss

# --- Correction ---
JDET_THRESHOLD = 0.01

# --- Output ---
OUTPUT_DIR = 'output/voxelmorph'
os.makedirs(OUTPUT_DIR, exist_ok=True)

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Device: {DEVICE}')

# %% [markdown]
# ## Generate synthetic 2D dataset
#
# Each image contains 1–4 randomly placed circles/ellipses with varying
# intensities on a dark background.  This gives the network enough variety
# to learn a general displacement field.

# %%
def make_random_image(size, rng):
    """Generate a single synthetic 2D image with random ellipses."""
    img = np.zeros((size, size), dtype=np.float32)
    yy, xx = np.mgrid[0:size, 0:size].astype(np.float32)

    n_shapes = rng.integers(1, 5)
    for _ in range(n_shapes):
        cy = rng.uniform(size * 0.15, size * 0.85)
        cx = rng.uniform(size * 0.15, size * 0.85)
        ry = rng.uniform(size * 0.06, size * 0.25)
        rx = rng.uniform(size * 0.06, size * 0.25)
        intensity = rng.uniform(0.3, 1.0)
        mask = ((yy - cy) / ry) ** 2 + ((xx - cx) / rx) ** 2 <= 1.0
        img[mask] = intensity

    return img


rng = np.random.default_rng(42)
n_total = NUM_TRAIN_IMAGES + NUM_TEST_PAIRS * 2  # test needs pairs
images = np.stack([make_random_image(IMAGE_SIZE, rng) for _ in range(n_total)])
train_images = images[:NUM_TRAIN_IMAGES]
test_images = images[NUM_TRAIN_IMAGES:]

print(f'Training images : {train_images.shape}')
print(f'Test images     : {test_images.shape}')

# Quick preview
fig, axes = plt.subplots(1, 6, figsize=(14, 2.5))
for i, ax in enumerate(axes):
    ax.imshow(train_images[i], cmap='gray', vmin=0, vmax=1)
    ax.set_title(f'#{i}')
    ax.axis('off')
fig.suptitle('Sample training images')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Build VoxelMorph model

# %%
model = vxm.nn.models.VxmPairwise(
    ndim=2,
    source_channels=1,
    target_channels=1,
    nb_features=NB_FEATURES,
    integration_steps=INTEGRATION_STEPS,
    device=DEVICE,
).to(DEVICE)

print(f'Model parameters: {sum(p.numel() for p in model.parameters()):,}')

# %% [markdown]
# ## Train
#
# Unsupervised scan-to-scan training: each step draws a random pair of
# images.  Losses:
# - **Image loss** (MSE): reconstructed target should match the actual target
# - **Smoothness loss** (spatial gradient L2): keeps the displacement field smooth

# %%
image_loss_fn = ne.nn.modules.MSE()
grad_loss_fn = ne.nn.modules.SpatialGradient('l2')
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

train_tensor = torch.from_numpy(train_images).float().unsqueeze(1).to(DEVICE)  # (N,1,H,W)
n_train = train_tensor.shape[0]

epoch_losses = []
t0 = time.perf_counter()

model.train()
for epoch in range(EPOCHS):
    epoch_loss = 0.0
    for _ in range(STEPS_PER_EPOCH):
        # Random pair
        idx = torch.randint(0, n_train, (2,))
        source = train_tensor[idx[0]].unsqueeze(0)  # (1,1,H,W)
        target = train_tensor[idx[1]].unsqueeze(0)

        optimizer.zero_grad()
        displacement, warped = model(
            source, target,
            return_warped_source=True,
            return_field_type='displacement',
        )

        img_loss = image_loss_fn(target, warped)
        smooth_loss = grad_loss_fn(displacement)
        loss = img_loss + LAMBDA_SMOOTH * smooth_loss
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

    avg = epoch_loss / STEPS_PER_EPOCH
    epoch_losses.append(avg)
    if (epoch + 1) % 20 == 0 or epoch == 0:
        print(f'Epoch {epoch+1:>4d}/{EPOCHS}  loss={avg:.6f}')

elapsed = time.perf_counter() - t0
print(f'\nTraining completed in {elapsed:.1f}s')

# %%
plt.figure(figsize=(8, 3))
plt.plot(epoch_losses)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training loss')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Register test pairs & extract displacement fields
#
# For each test pair, run the trained model to get:
# - The **warped source** image
# - The **displacement field** `(1, 2, H, W)` → converted to project
#   convention `(3, 1, H, W)` with `[dz=0, dy, dx]`

# %%
model.eval()
test_results = []  # list of dicts

test_tensor = torch.from_numpy(test_images).float().unsqueeze(1).to(DEVICE)

with torch.no_grad():
    for i in range(NUM_TEST_PAIRS):
        source = test_tensor[2 * i].unsqueeze(0)
        target = test_tensor[2 * i + 1].unsqueeze(0)

        disp, warped = model(
            source, target,
            return_warped_source=True,
            return_field_type='displacement',
        )

        # disp: (1, 2, H, W) — VoxelMorph convention [dy, dx] for 2D
        disp_np = disp.cpu().numpy()[0]  # (2, H, W)

        # Convert to project convention: (3, 1, H, W) with [dz=0, dy, dx]
        H, W = disp_np.shape[1], disp_np.shape[2]
        deformation = np.zeros((3, 1, H, W), dtype=np.float64)
        deformation[1, 0] = disp_np[0]  # dy
        deformation[2, 0] = disp_np[1]  # dx

        test_results.append({
            'source': source.cpu().numpy()[0, 0],
            'target': target.cpu().numpy()[0, 0],
            'warped': warped.cpu().numpy()[0, 0],
            'deformation': deformation,
        })

print(f'Registered {len(test_results)} test pairs')

# %% [markdown]
# ### Preview registration results

# %%
fig, axes = plt.subplots(NUM_TEST_PAIRS, 3, figsize=(10, 3 * NUM_TEST_PAIRS))
if NUM_TEST_PAIRS == 1:
    axes = axes[np.newaxis, :]

for i, res in enumerate(test_results):
    for j, (img, label) in enumerate([
        (res['source'], 'Source (moving)'),
        (res['target'], 'Target (fixed)'),
        (res['warped'], 'Warped source'),
    ]):
        axes[i, j].imshow(img, cmap='gray', vmin=0, vmax=1)
        if i == 0:
            axes[i, j].set_title(label)
        axes[i, j].axis('off')
    axes[i, 0].set_ylabel(f'Pair {i}', fontsize=11)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Check Jacobian determinants
#
# Survey each test displacement field for negative Jacobian determinants.

# %%
print(f'{"Pair":>6s}  {"Size":>8s}  {"Neg Jdet":>10s}  {"Below thr":>10s}  {"Min Jdet":>10s}')
print('-' * 52)

for i, res in enumerate(test_results):
    deformation = res['deformation']
    phi = np.stack([deformation[1, 0], deformation[2, 0]])  # (2, H, W)
    jac = jacobian_det2D(phi)

    n_neg = int((jac <= 0).sum())
    n_below = int((jac <= JDET_THRESHOLD).sum())
    min_j = float(jac.min())
    H, W = deformation.shape[-2:]

    res['n_neg'] = n_neg
    res['n_below'] = n_below
    res['min_jdet'] = min_j

    print(f'{i:>6d}  {H:>3d}x{W:<3d}  {n_neg:>10d}  {n_below:>10d}  {min_j:>10.4f}')

# %% [markdown]
# ## Correct folding
#
# Run `iterative_parallel` on each displacement field that has negative
# Jacobian determinants.

# %%
for i, res in enumerate(test_results):
    deformation = res['deformation']
    n_neg = res['n_neg']

    if n_neg == 0:
        print(f'Pair {i}: no negative Jacobians — skipping')
        res['phi_corrected'] = None
        continue

    save_dir = os.path.join(OUTPUT_DIR, f'pair_{i}')
    print(f'\nPair {i}: correcting {n_neg} negative Jdet pixels ...')

    t0 = time.perf_counter()
    phi = iterative_parallel(
        deformation.copy(),
        save_path=save_dir,
        verbose=1,
        threshold=JDET_THRESHOLD,
    )
    elapsed = time.perf_counter() - t0

    jac_final = jacobian_det2D(phi)
    n_neg_final = int((jac_final <= 0).sum())
    min_jdet_final = float(jac_final.min())

    phi_init = np.stack([deformation[1, 0], deformation[2, 0]])
    l2 = float(np.sqrt(np.sum((phi - phi_init) ** 2)))

    print(f'  Time: {elapsed:.2f}s  |  neg Jdet: {n_neg} -> {n_neg_final}  '
          f'|  min Jdet: {res["min_jdet"]:.4f} -> {min_jdet_final:.4f}  |  L2: {l2:.4f}')

    res['phi_corrected'] = phi

# %% [markdown]
# ## Visualise
#
# Show deformation grids and neighbourhoods for each corrected pair.

# %%
for i, res in enumerate(test_results):
    phi = res.get('phi_corrected')
    if phi is None:
        continue

    deformation = res['deformation']
    title = f'VoxelMorph pair {i}'

    plot_grid_before_after(deformation, phi, title=title)
    plot_checkerboard_before_after(deformation, phi, title=title)
    plot_neg_jdet_neighborhoods(deformation, phi, title=title)

# %% [markdown]
# ## Summary

# %%
print(f'{"Pair":>6s}  {"Neg (init)":>12s}  {"Neg (final)":>12s}  {"Min Jdet":>10s}  {"Corrected":>10s}')
print('-' * 58)

for i, res in enumerate(test_results):
    phi = res.get('phi_corrected')
    if phi is not None:
        jac = jacobian_det2D(phi)
        n_neg_f = int((jac <= 0).sum())
        min_j_f = float(jac.min())
    else:
        n_neg_f = 0
        min_j_f = res['min_jdet']

    corrected = 'yes' if phi is not None else 'no'
    print(f'{i:>6d}  {res["n_neg"]:>12d}  {n_neg_f:>12d}  {min_j_f:>10.4f}  {corrected:>10s}')

# %% [markdown]
# ## (Optional) Increase folding for demonstration
#
# If the trained model produced mostly smooth (fold-free) fields, lower
# `LAMBDA_SMOOTH` (e.g. to `0.001`) and retrain, or set
# `INTEGRATION_STEPS = 0` to disable diffeomorphic integration — this
# typically yields displacement fields with more folding.
